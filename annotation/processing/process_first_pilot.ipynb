# %%
import os
import pickle
from pathlib import Path
import json

import pandas as pd
import numpy as np

# %%
# open examples
pilot_path = '/home/jose/drive/data/lared_laughter/pilot2'
laughter_examples_df = pd.read_csv(os.path.join(pilot_path, 'laughter_examples', 'examples.csv'), index_col=0)
speech_examples_df = pd.read_csv(os.path.join(pilot_path, 'speech_examples', 'examples.csv'), index_col=0)

# %%
laughter_examples_df.head()
# Out:
#    id  pid  cam  valid                                               hash  \
# 0 NaN    1    2   True  3697019e90ec3c36979d8f5d97bd87e12b09cb83640554...
# 1 NaN    1    3   True  bbbb2623b09bcb1896967141eedf5c56aec51379bfdc1e...
# 2 NaN    1    4   True  24db998367045b41ad6990ee79cb650dd2329b3c899939...
# 3 NaN    1    2   True  533467606958d0cf5ebdd394172b5f975b14d3fa3121b6...
# 4 NaN    1    3   True  a5c3063d3e9a55b9426fd67c84ac0bc82cb605d8c70e82...
#
#    _ini_time  _end_time     ini_time     end_time  \
# 0    1028.28    1030.08  1026.363079  1032.543362
# 1    1028.28    1030.08  1026.363079  1032.543362
# 2    1028.28    1030.08  1026.363079  1032.543362
# 3    1049.98    1051.30  1047.638924  1054.518364
# 4    1049.98    1051.30  1047.638924  1054.518364
#
#                                           labels rect  ini  len
# 0  {'vad': None, 'label': None, 'vad_seg': None}  NaN  NaN  NaN
# 1  {'vad': None, 'label': None, 'vad_seg': None}  NaN  NaN  NaN
# 2  {'vad': None, 'label': None, 'vad_seg': None}  NaN  NaN  NaN
# 3  {'vad': None, 'label': None, 'vad_seg': None}  NaN  NaN  NaN
# 4  {'vad': None, 'label': None, 'vad_seg': None}  NaN  NaN  NaN

# %%
laughter_examples = {row['hash']: {
    'ini': row['_ini_time'] - row['ini_time'],
    'end': row['_end_time'] - row['ini_time']
} for _, row in laughter_examples_df.iterrows()}

# %%
speech_examples = {row['hash']: {
    'ini': row['_ini_time'],
    'end': row['_end_time']
} for _, row in speech_examples_df.iterrows()}

# %%
# open pilot json
pilot = json.load(open('../first_pilot.covfee.json'))

# %%
# open results
results_path = os.path.join(pilot_path, 'results/csv_download')
p = Path(results_path)

# %%
hit_to_hittype = {
    '2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5c22245f66e5afbf0da': 0,
    'ebad2c51dc19502f1c8a4bad375c4e07087449b34790de075cb9b75d0ff548a7': 0,
    'd4fbeffb2346462b59e7cb8ad392552c8ca2a44e0341892b489090d129b74e1d': 1,
    '3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6dfc1411d69c36ee5c83f': 2,
    '2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57bfa6d7a8f7a1975a2a': 2,
    '3b378a0ce8c12b08324020d11809e6329fe0ae32c15e4bae86e26d9682aa70a9': 2
}
old_hits = [
    '2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5c22245f66e5afbf0da',
    'ebad2c51dc19502f1c8a4bad375c4e07087449b34790de075cb9b75d0ff548a7',
    'd4fbeffb2346462b59e7cb8ad392552c8ca2a44e0341892b489090d129b74e1d'
]

# %%
filemap = {}
for dir in p.iterdir():
    hit_id = os.path.basename(dir)

    filemap = {}
    for f in os.listdir(dir):
        if f[0] == '.': continue
        idx = int(f.split('_')[0])
        if idx not in filemap:
            filemap[idx] = []
        filemap[idx].append(f)

# %%
filemap
# Out:
# {81: ['81_#35: Recognition_0.json', '81_#35: Recognition_0.csv'],
#  116: ['116_#11: Recognition_0.json', '116_#11: Recognition_0.csv'],
#  60: ['60_#24: Rating_0.json'],
#  231: ['231_#25: Recognition_0.csv', '231_#25: Recognition_0.json'],
#  12: ['12_#1: Rating_0.json'],
#  238: ['238_#28: Rating_0.json'],
#  102: ['102_#4: Recognition_0.csv', '102_#4: Recognition_0.json'],
#  213: ['213_#17: Recognition_0.json',
#   '213_#17: Recognition_1.csv',
#   '213_#17: Recognition_0.csv',
#   '213_#17: Recognition_1.json'],
#  214: ['214_#17: Rating_0.json'],
#  59: ['59_#24: Recognition_0.json', '59_#24: Recognition_0.csv'],
#  94: ['94_Calibration: Recognition_0.csv',
#   '94_Calibration: Recognition_1.json',
#   '94_Calibration: Recognition_1.csv',
#   '94_Calibration: Recognition_0.json'],
#  139: ['139_#21: Rating_0.json'],
#  143: ['143_#23: Rating_0.json'],
#  171: ['171_#37: Rating_0.json'],
#  146: ['146_#25: Recognition_0.json', '146_#25: Recognition_0.csv'],
#  13: ['13_#2: Recognition_0.csv', '13_#2: Recognition_0.json'],
#  133: ['133_#19: Rating_0.json'],
#  73: ['73_#31: Recognition_0.json', '73_#31: Recognition_0.csv'],
#  51: ['51_Calibration: Recognition_0.csv',
#   '51_Calibration: Recognition_0.json'],
#  33: ['33_#12: Recognition_0.json', '33_#12: Recognition_0.csv'],
#  35: ['35_#13: Recognition_0.csv', '35_#13: Recognition_0.json'],
#  144: ['144_#24: Recognition_0.csv', '144_#24: Recognition_0.json'],
#  176: ['176_#40: Recognition_0.csv', '176_#40: Recognition_0.json'],
#  45: ['45_#18: Recognition_0.csv', '45_#18: Recognition_0.json'],
#  21: ['21_#6: Recognition_0.json', '21_#6: Recognition_0.csv'],
#  16: ['16_#3: Rating_0.json'],
#  37: ['37_#14: Recognition_1.csv',
#   '37_#14: Recognition_0.csv',
#   '37_#14: Recognition_0.json',
#   '37_#14: Recognition_1.json'],
#  248: ['248_#33: Rating_0.json'],
#  106: ['106_#6: Recognition_0.csv', '106_#6: Recognition_0.json'],
#  244: ['244_#31: Rating_0.json'],
#  19: ['19_#5: Recognition_0.csv', '19_#5: Recognition_0.json'],
#  162: ['162_#33: Recognition_0.csv', '162_#33: Recognition_0.json'],
#  258: ['258_#38: Rating_0.json'],
#  119: ['119_#12: Rating_0.json'],
#  32: ['32_#11: Rating_0.json'],
#  72: ['72_#30: Rating_0.json'],
#  233: ['233_#26: Recognition_0.csv', '233_#26: Recognition_0.json'],
#  187: ['187_#4: Recognition_0.json', '187_#4: Recognition_0.csv'],
#  25: ['25_#8: Recognition_0.csv', '25_#8: Recognition_0.json'],
#  235: ['235_#27: Recognition_0.json', '235_#27: Recognition_0.csv'],
#  79: ['79_#34: Recognition_0.csv', '79_#34: Recognition_0.json'],
#  156: ['156_#30: Recognition_0.json', '156_#30: Recognition_0.csv'],
#  257: ['257_#38: Recognition_0.json', '257_#38: Recognition_0.csv'],
#  243: ['243_#31: Recognition_0.csv', '243_#31: Recognition_0.json'],
#  219: ['219_#20: Recognition_0.json', '219_#20: Recognition_0.csv'],
#  9: ['9_Calibration: Recognition_0.csv', '9_Calibration: Recognition_0.json'],
#  77: ['77_#33: Recognition_1.csv',
#   '77_#33: Recognition_0.csv',
#   '77_#33: Recognition_0.json',
#   '77_#33: Recognition_1.json'],
#  55: ['55_#22: Recognition_0.json', '55_#22: Recognition_0.csv'],
#  11: ['11_#1: Recognition_0.csv', '11_#1: Recognition_0.json'],
#  57: ['57_#23: Recognition_0.csv', '57_#23: Recognition_0.json'],
#  134: ['134_#20: Recognition_0.csv', '134_#20: Recognition_0.json'],
#  14: ['14_#2: Rating_0.json'],
#  136: ['136_Calibration: Recognition_0.csv',
#   '136_Calibration: Recognition_0.json'],
#  207: ['207_#14: Recognition_0.json',
#   '207_#14: Recognition_0.csv',
#   '207_#14: Recognition_1.csv',
#   '207_#14: Recognition_1.json'],
#  234: ['234_#26: Rating_0.json'],
#  39: ['39_#15: Recognition_0.json', '39_#15: Recognition_0.csv'],
#  166: ['166_#35: Recognition_0.csv', '166_#35: Recognition_0.json'],
#  149: ['149_#26: Rating_0.json'],
#  75: ['75_#32: Recognition_1.json',
#   '75_#32: Recognition_0.csv',
#   '75_#32: Recognition_0.json',
#   '75_#32: Recognition_1.csv'],
#  107: ['107_#6: Rating_0.json'],
#  184: ['184_#2: Rating_0.json'],
#  193: ['193_#7: Recognition_0.json', '193_#7: Recognition_0.csv'],
#  93: ['93_Audio-only instructions_0.json'],
#  172: ['172_#38: Recognition_0.json', '172_#38: Recognition_0.csv'],
#  85: ['85_#37: Recognition_0.csv', '85_#37: Recognition_0.json'],
#  2: ['2_Example #1: Recognition_0.json', '2_Example #1: Recognition_0.csv'],
#  121: ['121_#13: Rating_0.json'],
#  127: ['127_#16: Rating_0.json'],
#  78: ['78_#33: Rating_0.json'],
#  185: ['185_#3: Recognition_0.csv', '185_#3: Recognition_0.json'],
#  104: ['104_#5: Recognition_0.csv', '104_#5: Recognition_0.json'],
#  206: ['206_#13: Rating_0.json'],
#  23: ['23_#7: Recognition_0.json', '23_#7: Recognition_0.csv'],
#  197: ['197_#9: Recognition_0.json', '197_#9: Recognition_0.csv'],
#  113: ['113_#9: Rating_0.json'],
#  130: ['130_#18: Recognition_0.json', '130_#18: Recognition_0.csv'],
#  86: ['86_#37: Rating_0.json'],
#  98: ['98_#2: Recognition_0.csv', '98_#2: Recognition_0.json'],
#  53: ['53_#21: Recognition_0.json', '53_#21: Recognition_0.csv'],
#  82: ['82_#35: Rating_0.json'],
#  84: ['84_#36: Rating_0.json'],
#  27: ['27_#9: Recognition_0.json', '27_#9: Recognition_0.csv'],
#  224: ['224_#21: Rating_0.json'],
#  211: ['211_#16: Recognition_0.json', '211_#16: Recognition_0.csv'],
#  249: ['249_#34: Recognition_1.json',
#   '249_#34: Recognition_0.csv',
#   '249_#34: Recognition_0.json',
#   '249_#34: Recognition_1.csv'],
#  31: ['31_#11: Recognition_0.json', '31_#11: Recognition_0.csv'],
#  95: ['95_Calibration: Rating_0.json'],
#  209: ['209_#15: Recognition_0.csv', '209_#15: Recognition_0.json'],
#  179: ['179_Calibration: Recognition_0.json',
#   '179_Calibration: Recognition_0.csv'],
#  247: ['247_#33: Recognition_0.json', '247_#33: Recognition_0.csv'],
#  5: ['5_Example #2: Rating_0.json'],
#  254: ['254_#36: Rating_0.json'],
#  181: ['181_#1: Recognition_0.json', '181_#1: Recognition_0.csv'],
#  122: ['122_#14: Recognition_0.csv', '122_#14: Recognition_0.json'],
#  250: ['250_#34: Rating_0.json'],
#  29: ['29_#10: Recognition_0.json',
#   '29_#10: Recognition_1.csv',
#   '29_#10: Recognition_1.json',
#   '29_#10: Recognition_0.csv'],
#  237: ['237_#28: Recognition_0.json', '237_#28: Recognition_0.csv'],
#  4: ['4_Example #2: Recognition_0.json', '4_Example #2: Recognition_0.csv'],
#  198: ['198_#9: Rating_0.json'],
#  261: ['261_#40: Recognition_1.csv',
#   '261_#40: Recognition_0.json',
#   '261_#40: Recognition_0.csv',
#   '261_#40: Recognition_1.json'],
#  65: ['65_#27: Recognition_0.json', '65_#27: Recognition_0.csv'],
#  183: ['183_#2: Recognition_0.csv', '183_#2: Recognition_0.json'],
#  196: ['196_#8: Rating_0.json'],
#  24: ['24_#7: Rating_0.json'],
#  241: ['241_#30: Recognition_0.csv', '241_#30: Recognition_0.json'],
#  71: ['71_#30: Recognition_0.csv', '71_#30: Recognition_0.json'],
#  44: ['44_#17: Rating_0.json'],
#  167: ['167_#35: Rating_0.json'],
#  114: ['114_#10: Recognition_1.json',
#   '114_#10: Recognition_0.csv',
#   '114_#10: Recognition_1.csv',
#   '114_#10: Recognition_0.json'],
#  0: ['0_Consent_0.json'],
#  132: ['132_#19: Recognition_0.json', '132_#19: Recognition_0.csv'],
#  138: ['138_#21: Recognition_0.csv', '138_#21: Recognition_0.json'],
#  174: ['174_#39: Recognition_0.json', '174_#39: Recognition_0.csv'],
#  100: ['100_#3: Recognition_0.json', '100_#3: Recognition_0.csv'],
#  112: ['112_#9: Recognition_0.csv', '112_#9: Recognition_0.json'],
#  251: ['251_#35: Recognition_0.json', '251_#35: Recognition_0.csv'],
#  76: ['76_#32: Rating_0.json'],
#  8: ['8_Video-only instructions_0.json'],
#  165: ['165_#34: Rating_0.json'],
#  153: ['153_#28: Rating_0.json'],
#  217: ['217_#19: Recognition_0.csv', '217_#19: Recognition_0.json'],
#  49: ['49_#20: Recognition_0.csv', '49_#20: Recognition_0.json'],
#  96: ['96_#1: Recognition_0.json', '96_#1: Recognition_0.csv'],
#  203: ['203_#12: Recognition_0.json', '203_#12: Recognition_0.csv'],
#  208: ['208_#14: Rating_0.json'],
#  91: ['91_#40: Recognition_0.json', '91_#40: Recognition_0.csv'],
#  117: ['117_#11: Rating_0.json'],
#  160: ['160_#32: Recognition_0.json', '160_#32: Recognition_0.csv'],
#  47: ['47_#19: Recognition_0.json', '47_#19: Recognition_0.csv'],
#  120: ['120_#13: Recognition_0.json', '120_#13: Recognition_0.csv'],
#  87: ['87_#38: Recognition_0.csv', '87_#38: Recognition_0.json'],
#  221: ['221_Calibration: Recognition_0.json',
#   '221_Calibration: Recognition_0.csv'],
#  124: ['124_#15: Recognition_0.json', '124_#15: Recognition_0.csv'],
#  220: ['220_#20: Rating_0.json'],
#  88: ['88_#38: Rating_0.json'],
#  61: ['61_#25: Recognition_0.csv', '61_#25: Recognition_0.json'],
#  170: ['170_#37: Recognition_0.csv', '170_#37: Recognition_0.json'],
#  58: ['58_#23: Rating_0.json'],
#  74: ['74_#31: Rating_0.json'],
#  204: ['204_#12: Rating_0.json'],
#  229: ['229_#24: Recognition_0.json', '229_#24: Recognition_0.csv'],
#  142: ['142_#23: Recognition_0.csv', '142_#23: Recognition_0.json'],
#  157: ['157_#30: Rating_0.json'],
#  173: ['173_#38: Rating_0.json'],
#  200: ['200_#10: Rating_0.json'],
#  230: ['230_#24: Rating_0.json'],
#  62: ['62_#25: Rating_0.json'],
#  255: ['255_#37: Recognition_0.csv', '255_#37: Recognition_0.json'],
#  199: ['199_#10: Recognition_0.json', '199_#10: Recognition_0.csv'],
#  151: ['151_#27: Rating_0.json'],
#  118: ['118_#12: Recognition_0.csv',
#   '118_#12: Recognition_1.csv',
#   '118_#12: Recognition_1.json',
#   '118_#12: Recognition_0.json'],
#  38: ['38_#14: Rating_0.json'],
#  216: ['216_#18: Rating_0.json'],
#  108: ['108_#7: Recognition_0.json', '108_#7: Recognition_0.csv'],
#  253: ['253_#36: Recognition_0.json', '253_#36: Recognition_0.csv'],
#  43: ['43_#17: Recognition_0.json', '43_#17: Recognition_0.csv'],
#  34: ['34_#12: Rating_0.json'],
#  218: ['218_#19: Rating_0.json'],
#  70: ['70_#29: Rating_0.json'],
#  90: ['90_#39: Rating_0.json'],
#  154: ['154_#29: Recognition_0.csv', '154_#29: Recognition_0.json'],
#  89: ['89_#39: Recognition_0.json', '89_#39: Recognition_0.csv'],
#  227: ['227_#23: Recognition_0.json', '227_#23: Recognition_0.csv'],
#  46: ['46_#18: Rating_0.json'],
#  110: ['110_#8: Recognition_0.json', '110_#8: Recognition_0.csv'],
#  189: ['189_#5: Recognition_0.csv', '189_#5: Recognition_0.json'],
#  126: ['126_#16: Recognition_0.json', '126_#16: Recognition_0.csv'],
#  28: ['28_#9: Rating_0.json'],
#  225: ['225_#22: Recognition_0.csv', '225_#22: Recognition_0.json'],
#  145: ['145_#24: Rating_0.json'],
#  262: ['262_#40: Rating_0.json'],
#  240: ['240_#29: Rating_0.json'],
#  252: ['252_#35: Rating_0.json'],
#  150: ['150_#27: Recognition_0.json', '150_#27: Recognition_0.csv'],
#  186: ['186_#3: Rating_0.json'],
#  15: ['15_#3: Recognition_0.csv', '15_#3: Recognition_0.json'],
#  155: ['155_#29: Rating_0.json'],
#  202: ['202_#11: Rating_0.json'],
#  236: ['236_#27: Rating_0.json'],
#  168: ['168_#36: Recognition_0.csv', '168_#36: Recognition_0.json'],
#  201: ['201_#11: Recognition_0.json', '201_#11: Recognition_0.csv'],
#  180: ['180_Calibration: Rating_0.json'],
#  50: ['50_#20: Rating_0.json'],
#  215: ['215_#18: Recognition_0.csv', '215_#18: Recognition_0.json'],
#  18: ['18_#4: Rating_0.json'],
#  105: ['105_#5: Rating_0.json'],
#  161: ['161_#32: Rating_0.json'],
#  131: ['131_#18: Rating_0.json'],
#  256: ['256_#37: Rating_0.json'],
#  20: ['20_#5: Rating_0.json'],
#  111: ['111_#8: Rating_0.json'],
#  109: ['109_#7: Rating_0.json'],
#  232: ['232_#25: Rating_0.json'],
#  6: ['6_Example #3: Recognition_0.json', '6_Example #3: Recognition_0.csv'],
#  148: ['148_#26: Recognition_0.json', '148_#26: Recognition_0.csv'],
#  239: ['239_#29: Recognition_0.json',
#   '239_#29: Recognition_1.csv',
#   '239_#29: Recognition_0.csv',
#   '239_#29: Recognition_1.json'],
#  158: ['158_#31: Recognition_0.json', '158_#31: Recognition_0.csv'],
#  226: ['226_#22: Rating_0.json'],
#  69: ['69_#29: Recognition_0.json', '69_#29: Recognition_0.csv'],
#  178: ['178_Audiovisual instructions_0.json'],
#  66: ['66_#27: Rating_0.json'],
#  212: ['212_#16: Rating_0.json'],
#  97: ['97_#1: Rating_0.json'],
#  1: ['1_General Instructions_0.json'],
#  17: ['17_#4: Recognition_0.json', '17_#4: Recognition_0.csv'],
#  129: ['129_#17: Rating_0.json'],
#  175: ['175_#39: Rating_0.json'],
#  63: ['63_#26: Recognition_0.json', '63_#26: Recognition_0.csv'],
#  30: ['30_#10: Rating_0.json'],
#  245: ['245_#32: Recognition_0.json', '245_#32: Recognition_0.csv'],
#  205: ['205_#13: Recognition_0.json', '205_#13: Recognition_0.csv'],
#  125: ['125_#15: Rating_0.json'],
#  194: ['194_#7: Rating_0.json'],
#  137: ['137_Calibration: Rating_0.json'],
#  80: ['80_#34: Rating_0.json'],
#  152: ['152_#28: Recognition_0.json', '152_#28: Recognition_0.csv'],
#  52: ['52_Calibration: Rating_0.json'],
#  222: ['222_Calibration: Rating_0.json'],
#  182: ['182_#1: Rating_0.json'],
#  169: ['169_#36: Rating_0.json'],
#  223: ['223_#21: Recognition_0.json', '223_#21: Recognition_0.csv'],
#  191: ['191_#6: Recognition_0.csv', '191_#6: Recognition_0.json'],
#  83: ['83_#36: Recognition_0.csv', '83_#36: Recognition_0.json'],
#  188: ['188_#4: Rating_0.json'],
#  3: ['3_Example #1: Rating_0.json'],
#  195: ['195_#8: Recognition_0.json', '195_#8: Recognition_0.csv'],
#  164: ['164_#34: Recognition_0.csv', '164_#34: Recognition_0.json'],
#  192: ['192_#6: Rating_0.json'],
#  140: ['140_#22: Recognition_0.json', '140_#22: Recognition_0.csv'],
#  115: ['115_#10: Rating_0.json'],
#  123: ['123_#14: Rating_0.json'],
#  41: ['41_#16: Recognition_0.json', '41_#16: Recognition_0.csv'],
#  54: ['54_#21: Rating_0.json'],
#  67: ['67_#28: Recognition_0.csv', '67_#28: Recognition_0.json'],
#  64: ['64_#26: Rating_0.json'],
#  22: ['22_#6: Rating_0.json'],
#  141: ['141_#22: Rating_0.json'],
#  10: ['10_Calibration: Rating_0.json'],
#  135: ['135_#20: Rating_0.json'],
#  163: ['163_#33: Rating_0.json'],
#  177: ['177_#40: Rating_0.json'],
#  128: ['128_#17: Recognition_0.json', '128_#17: Recognition_0.csv'],
#  228: ['228_#23: Rating_0.json'],
#  101: ['101_#3: Rating_0.json'],
#  92: ['92_#40: Rating_0.json'],
#  259: ['259_#39: Recognition_0.json', '259_#39: Recognition_0.csv'],
#  40: ['40_#15: Rating_0.json'],
#  36: ['36_#13: Rating_0.json'],
#  147: ['147_#25: Rating_0.json'],
#  48: ['48_#19: Rating_0.json'],
#  210: ['210_#15: Rating_0.json'],
#  242: ['242_#30: Rating_0.json'],
#  7: ['7_Example #3: Rating_0.json'],
#  260: ['260_#39: Rating_0.json'],
#  56: ['56_#22: Rating_0.json'],
#  26: ['26_#8: Rating_0.json'],
#  103: ['103_#4: Rating_0.json'],
#  99: ['99_#2: Rating_0.json'],
#  42: ['42_#16: Rating_0.json'],
#  159: ['159_#31: Rating_0.json'],
#  263: ['263_Feedback_0.json'],
#  246: ['246_#32: Rating_0.json'],
#  190: ['190_#5: Rating_0.json'],
#  68: ['68_#28: Rating_0.json']}

# %%
continuous_annotations = []
results_dict = []
for dir in p.iterdir():
    hit_id = os.path.basename(dir)
    hit_type = hit_to_hittype[hit_id]

    num_segments = 0
    for json_file in dir.glob('*.json'):
        # get example index
        fname = os.path.basename(json_file).split('.')[0]
        if 'Rating' not in fname or 'Example' in fname:
            continue
        index_in_hit = int(fname.split('_')[0])
        if hit_id in old_hits:
            index_in_hit += 7
        example_url = pilot['hits'][hit_type]['tasks'][index_in_hit]['media']['url']
        example_hash = example_url.split('/')[-1].split('_')[1]
        condition = example_url.split('/')[-2]
        if condition == 'aiv':
            condition = 'audio'
        
        is_calibration = 'Calibration' in fname

        # read the json response
        json_res = json.load(open(json_file))['response']
        if not json_res:
            json_res = {}

        # read the continuous data
        index = int(fname.split('_')[0])-1
        number_chunk = fname.split('_')[1].split(':')[0]
        second_response_file = os.path.join(dir, f'{index}_{number_chunk}: Recognition_1.csv')
        first_response_file = os.path.join(dir, f'{index}_{number_chunk}: Recognition_0.csv')

        attempt = None
        if os.path.exists(second_response_file):
            attempt = 1
            response_file = second_response_file
        elif os.path.exists(first_response_file):
            attempt = 0
            response_file = first_response_file
        else:
            print(f'no continous response {first_response_file} or {second_response_file}')

        cont_data = pd.read_csv(response_file, index_col=0, header=0)
        pressed_key = cont_data['data0'].any()
        
        # get the ground truth
        if example_hash in laughter_examples:
            # print('found in laughter')
            gt_ini = laughter_examples[example_hash]['ini']
            gt_end = laughter_examples[example_hash]['end']
            gt_laughter = True
        elif example_hash in speech_examples:
            # print('found in speech')
            gt_ini = None
            gt_end = None
            gt_laughter = False
        else:
            raise Exception(f'example hash {example_hash} not found anywhere')

        continuous_annotations.append(cont_data[['media_time', 'data0']].to_numpy())

        results_dict.append({
            'person': None, 
            'hit_id': hit_id, 
            'calibration': is_calibration,
            'condition': condition,
            'hash': example_hash,
            'attempt': attempt,
            'gt_ini': gt_ini,
            'gt_end': gt_end,
            'gt_laughter': gt_laughter,
            'pressed_key': pressed_key,
            'onset': cont_data[cont_data['data0'] == 1].iloc[0]['media_time'] if pressed_key else None,
            'offset': cont_data[cont_data['data0'] == 1].iloc[-1]['media_time'] if pressed_key else None,
            'is_laughter': json_res.get('laughter', None),
            'confidence': json_res.get('confidence', None),
            'intensity': json_res.get('intensity', None)
        })
        num_segments += 1
    print(f'HIT {hit_id}, segments: {num_segments}')
# Out:
# HIT 2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57bfa6d7a8f7a1975a2a, segments: 126
# HIT 3b378a0ce8c12b08324020d11809e6329fe0ae32c15e4bae86e26d9682aa70a9, segments: 17
# HIT 2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5c22245f66e5afbf0da, segments: 126
# HIT ebad2c51dc19502f1c8a4bad375c4e07087449b34790de075cb9b75d0ff548a7, segments: 43
# HIT d4fbeffb2346462b59e7cb8ad392552c8ca2a44e0341892b489090d129b74e1d, segments: 126
# HIT 3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6dfc1411d69c36ee5c83f, segments: 126

# %%
results = pd.DataFrame.from_dict(results_dict)
len(results)
# Out:
# 564

# %%
results.drop(['hit_id'], axis=1).head(20)
# Out:
#    person  calibration condition  \
# 0    None        False     video
# 1    None        False     video
# 2    None        False        av
# 3    None        False        av
# 4    None        False     audio
# 5    None        False     audio
# 6    None        False     audio
# 7    None        False     audio
# 8    None        False     video
# 9    None        False        av
# 10   None        False        av
# 11   None        False        av
# 12   None        False     audio
# 13   None        False     video
# 14   None        False     video
# 15   None        False     video
# 16   None        False        av
# 17   None        False     audio
# 18   None        False     audio
# 19   None        False        av
#
#                                                  hash  attempt    gt_ini  \
# 0   c04425157021aec61593af1ad0f98d3cb6bfdd1e722060...        0  1.919661
# 1   4c33f28fdfd04e773bcaffcd7cb3ae4d98f2455744bb21...        0  3.204874
# 2   4e94802c123eb9f6060854f9ed0121cb9c1e4ba44708b9...        0  1.653297
# 3   11866b5358caabe46c4528bfc49de7579363607700b1cc...        0  3.272997
# 4   8e4201ed4e84ac8d937fb6bb92aec9b8feb53b51fb3622...        0       NaN
# 5   8f31104e99128232be56331eb2fad4486fc9a4d49f0048...        0       NaN
# 6   fcce19ded1b21bd5a7d511d6e0d8876b5bffe42d1ed24c...        0       NaN
# 7   dbaabe4af355ea52813edd36b7ca92d971961e5671ebc8...        0  2.202106
# 8   8108b1733b1c13aef1276dd2e7e55be37a573c63788d5d...        0       NaN
# 9   6a86605aa53c2936f608d55ae654614dde87bacfbadcb8...        0  2.928600
# 10  6a5db287546f5c05d54c3d42534d164f80a69a5c5e9f25...        0  2.581648
# 11  069d300af9889ef9b177b0158193da139d6872b5edd3b7...        0  2.900185
# 12  ee957b754c1c83cec664dc97d6788cac15cea86f7f8060...        0  1.630000
# 13  4b02434694fbfcc76276d3477a76a1a1c2483d589300bf...        0  1.647462
# 14  4ae73ac9f95da12fbf1ab758a1d5eb7c533d02ee26052d...        1  1.635998
# 15  b37bcb0997537153db15add71abd5d6a50864ac9578d7c...        0  1.754679
# 16  21bdfe6476fd698faec05e93458ba236e94f498cf5ad49...        0  2.726221
# 17  b596395d5c103a5b58c7ebff891e44802563982e702b14...        0  2.593899
# 18  b2fe398b0c8902971fa0c8c80e78cca0e9869091ff79d1...        0       NaN
# 19  1045f4f5af149c20d0bb3e7523013510912093312f6f56...        1       NaN
#
#       gt_end  gt_laughter  pressed_key     onset     offset is_laughter  \
# 0   2.785661         True         True  3.436770   4.471138        True
# 1   6.564874         True         True  3.536870   6.006006        True
# 2   2.393297         True         True  2.292156   2.659189        True
# 3   5.272997         True         True  4.928125   5.762292        True
# 4        NaN        False        False       NaN        NaN       False
# 5        NaN        False        False       NaN        NaN       False
# 6        NaN        False        False       NaN        NaN       False
# 7   2.682106         True        False       NaN        NaN       False
# 8        NaN        False        False       NaN        NaN        True
# 9   5.962600         True         True  3.526724   6.396260        True
# 10  3.265648         True         True  3.092956   3.893757        True
# 11  4.400185         True         True  3.459990   4.494358        True
# 12  2.250000         True         True  2.703220   3.143220        True
# 13  2.030462         True         True  1.735068   3.436770        True
# 14  7.152998         True         True  1.935269   7.874541        True
# 15  5.520679         True        False       NaN        NaN        True
# 16  4.366221         True        False       NaN        NaN       False
# 17  3.413899         True         True  3.703220   4.183220        True
# 18       NaN        False        False       NaN        NaN       False
# 19       NaN        False         True  1.191055  10.600464        True
#
#     confidence  intensity
# 0          3.0        1.0
# 1          5.0        5.0
# 2          6.0        2.0
# 3          7.0        4.0
# 4          6.0        4.0
# 5          4.0        4.0
# 6          5.0        4.0
# 7          5.0        4.0
# 8          3.0        2.0
# 9          6.0        4.0
# 10         6.0        4.0
# 11         7.0        3.0
# 12         5.0        2.0
# 13         5.0        2.0
# 14         6.0        4.0
# 15         3.0        3.0
# 16         5.0        4.0
# 17         5.0        1.0
# 18         6.0        4.0
# 19         6.0        3.0

# %%
results.sort_values(by='hash').head(50)
# Out:
#     person                                             hit_id  calibration  \
# 203   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 38    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 287   None  ebad2c51dc19502f1c8a4bad375c4e07087449b34790de...        False
# 476   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 430   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 484   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 46    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 371   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 146   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 226   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 354   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 449   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 11    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 181   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 501   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 63    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 359   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 433   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...         True
# 91    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...         True
# 266   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...         True
# 529   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...         True
# 310   None  ebad2c51dc19502f1c8a4bad375c4e07087449b34790de...         True
# 457   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 19    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 427   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 247   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 422   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 3     None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 441   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 160   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 244   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 100   None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 322   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 538   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 469   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 31    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 373   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 182   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 454   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 361   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 153   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 16    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 149   None  2aa4cfd7a395f69d3e67a074bf63d3bb8f1ca0576daad5...        False
# 52    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 490   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 382   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
# 271   None  ebad2c51dc19502f1c8a4bad375c4e07087449b34790de...        False
# 83    None  2e1248ccfbcd0b52875f8632ef3c5c7a7016818f1f8d57...        False
# 521   None  3f48cb8025cd905c1a0f7eda7e70e93a3122a8310af6df...        False
# 413   None  d4fbeffb2346462b59e7cb8ad392552c8ca2a44e034189...        False
#
#     condition                                               hash  attempt  \
# 203     video  00daba0ee83b3793e7354632d3ab60a46a9b251e85f64b...        0
# 38      audio  00daba0ee83b3793e7354632d3ab60a46a9b251e85f64b...        0
# 287     video  00daba0ee83b3793e7354632d3ab60a46a9b251e85f64b...        0
# 476     audio  00daba0ee83b3793e7354632d3ab60a46a9b251e85f64b...        0
# 430        av  00daba0ee83b3793e7354632d3ab60a46a9b251e85f64b...        0
# 484        av  0657210cea7baa9d453f7bc16852ff5fdcdd6091a2bb2f...        0
# 46         av  0657210cea7baa9d453f7bc16852ff5fdcdd6091a2bb2f...        0
# 371     video  0657210cea7baa9d453f7bc16852ff5fdcdd6091a2bb2f...        0
# 146     audio  0657210cea7baa9d453f7bc16852ff5fdcdd6091a2bb2f...        0
# 226     audio  069d300af9889ef9b177b0158193da139d6872b5edd3b7...        0
# 354     video  069d300af9889ef9b177b0158193da139d6872b5edd3b7...        1
# 449        av  069d300af9889ef9b177b0158193da139d6872b5edd3b7...        0
# 11         av  069d300af9889ef9b177b0158193da139d6872b5edd3b7...        0
# 181     audio  0f30b81afc28da6a261208efbf1623846f3253825d235b...        0
# 501        av  0f30b81afc28da6a261208efbf1623846f3253825d235b...        1
# 63         av  0f30b81afc28da6a261208efbf1623846f3253825d235b...        0
# 359     video  0f30b81afc28da6a261208efbf1623846f3253825d235b...        1
# 433     video  0feb2d80d7e192750c723d7f70dd82b61f3e98de2a4375...        0
# 91      video  0feb2d80d7e192750c723d7f70dd82b61f3e98de2a4375...        0
# 266     video  0feb2d80d7e192750c723d7f70dd82b61f3e98de2a4375...        0
# 529     video  0feb2d80d7e192750c723d7f70dd82b61f3e98de2a4375...        0
# 310     video  0feb2d80d7e192750c723d7f70dd82b61f3e98de2a4375...        0
# 457        av  1045f4f5af149c20d0bb3e7523013510912093312f6f56...        0
# 19         av  1045f4f5af149c20d0bb3e7523013510912093312f6f56...        1
# 427     video  1045f4f5af149c20d0bb3e7523013510912093312f6f56...        0
# 247     audio  1045f4f5af149c20d0bb3e7523013510912093312f6f56...        0
# 422     video  11866b5358caabe46c4528bfc49de7579363607700b1cc...        0
# 3          av  11866b5358caabe46c4528bfc49de7579363607700b1cc...        0
# 441        av  11866b5358caabe46c4528bfc49de7579363607700b1cc...        1
# 160     audio  11866b5358caabe46c4528bfc49de7579363607700b1cc...        0
# 244        av  15422420846840e0319c3aa409b77dcad28633ea12a9af...        0
# 100     video  15422420846840e0319c3aa409b77dcad28633ea12a9af...        0
# 322     audio  15422420846840e0319c3aa409b77dcad28633ea12a9af...        1
# 538     video  15422420846840e0319c3aa409b77dcad28633ea12a9af...        0
# 469        av  2070ebb6b8c1d14e2e2ba906e4f666d8aa694461f0e03d...        1
# 31         av  2070ebb6b8c1d14e2e2ba906e4f666d8aa694461f0e03d...        0
# 373     video  2070ebb6b8c1d14e2e2ba906e4f666d8aa694461f0e03d...        0
# 182     audio  2070ebb6b8c1d14e2e2ba906e4f666d8aa694461f0e03d...        0
# 454        av  21bdfe6476fd698faec05e93458ba236e94f498cf5ad49...        0
# 361     video  21bdfe6476fd698faec05e93458ba236e94f498cf5ad49...        0
# 153     audio  21bdfe6476fd698faec05e93458ba236e94f498cf5ad49...        0
# 16         av  21bdfe6476fd698faec05e93458ba236e94f498cf5ad49...        0
# 149     video  26c33022483ed4a9b59227a77a4db6aae4561ecd349d69...        0
# 52      audio  26c33022483ed4a9b59227a77a4db6aae4561ecd349d69...        0
# 490     audio  26c33022483ed4a9b59227a77a4db6aae4561ecd349d69...        0
# 382        av  26c33022483ed4a9b59227a77a4db6aae4561ecd349d69...        0
# 271     video  26c33022483ed4a9b59227a77a4db6aae4561ecd349d69...        0
# 83      audio  2759d0b375625bae17084f5bb5f24ba9e9bab5b5fe59db...        0
# 521     audio  2759d0b375625bae17084f5bb5f24ba9e9bab5b5fe59db...        0
# 413        av  2759d0b375625bae17084f5bb5f24ba9e9bab5b5fe59db...        0
#
#        gt_ini    gt_end  gt_laughter  pressed_key     onset     offset  \
# 203       NaN       NaN        False        False       NaN        NaN
# 38        NaN       NaN        False        False       NaN        NaN
# 287       NaN       NaN        False        False       NaN        NaN
# 476       NaN       NaN        False        False       NaN        NaN
# 430       NaN       NaN        False        False       NaN        NaN
# 484  3.378759  4.898759         True         True  4.427624   4.894758
# 46   3.378759  4.898759         True         True  4.360891   4.761291
# 371  3.378759  4.898759         True         True  4.004004   4.371038
# 146  3.378759  4.898759         True         True  4.983220   5.143220
# 226  2.900185  4.400185         True         True  3.503220   4.663220
# 354  2.900185  4.400185         True         True  3.336670   5.872539
# 449  2.900185  4.400185         True         True  3.526724   4.727925
# 11   2.900185  4.400185         True         True  3.459990   4.494358
# 181  3.443280  4.503280         True         True  4.383220   5.943220
# 501  3.443280  4.503280         True         True  4.093957   5.395259
# 63   3.443280  4.503280         True         True  4.227424   5.028225
# 359  3.443280  4.503280         True         True  4.471138   6.239573
# 433  2.005387  3.285387         True         True  3.036370   4.571238
# 91   2.005387  3.285387         True         True  2.268936   4.571238
# 266  2.005387  3.285387         True         True  2.168836   4.571238
# 529  2.005387  3.285387         True         True  2.469136   4.070737
# 310  2.005387  3.285387         True         True  2.135469   4.037371
# 457       NaN       NaN        False         True  3.793657  11.367898
# 19        NaN       NaN        False         True  1.191055  10.600464
# 427       NaN       NaN        False        False       NaN        NaN
# 247       NaN       NaN        False         True  3.703220  10.543220
# 422  3.272997  5.272997         True         True  4.938272   6.006006
# 3    3.272997  5.272997         True         True  4.928125   5.762292
# 441  3.272997  5.272997         True         True  4.627825   5.528726
# 160  3.272997  5.272997         True         True  6.623220   7.143220
# 244  3.034819  3.667819         True         True  3.493357   3.893757
# 100  3.034819  3.667819         True         True  3.870537   4.471138
# 322  3.034819  3.667819         True         True  0.063220   3.823220
# 538  3.034819  3.667819         True        False       NaN        NaN
# 469  2.535113  4.995113         True         True  2.091955   3.827024
# 31   2.535113  4.995113         True         True  1.958489   4.994858
# 373  2.535113  4.995113         True         True  2.535869   3.536870
# 182  2.535113  4.995113         True         True  2.183220   2.303220
# 454  2.726221  4.366221         True        False       NaN        NaN
# 361  2.726221  4.366221         True         True  3.269937   5.972639
# 153  2.726221  4.366221         True        False       NaN        NaN
# 16   2.726221  4.366221         True        False       NaN        NaN
# 149  1.503134  2.320134         True         True  1.735068   4.204204
# 52   1.503134  2.320134         True         True  0.863220   2.623220
# 490  1.503134  2.320134         True         True  1.183220   2.943220
# 382  1.503134  2.320134         True         True  1.124321   2.158689
# 271  1.503134  2.320134         True         True  2.168836   5.238572
# 83   3.158258  4.358258         True         True  3.623220   4.863220
# 521  3.158258  4.358258         True         True  3.983220   4.943220
# 413  3.158258  4.358258         True         True  3.827024   5.161692
#
#     is_laughter  confidence  intensity
# 203       False         4.0        4.0
# 38        False         5.0        4.0
# 287       False         6.0        4.0
# 476       False         7.0        4.0
# 430       False         7.0        4.0
# 484        True         7.0        1.0
# 46         True         6.0        2.0
# 371        True         7.0        5.0
# 146        True         6.0        3.0
# 226        True         7.0        5.0
# 354        True         7.0        5.0
# 449        True         7.0        4.0
# 11         True         7.0        3.0
# 181        True         7.0        3.0
# 501        True         7.0        5.0
# 63         True         6.0        3.0
# 359        True         1.0        2.0
# 433        None         NaN        NaN
# 91         True         6.0        4.0
# 266        None         NaN        NaN
# 529        True         7.0        3.0
# 310        None         NaN        NaN
# 457        True         7.0        3.0
# 19         True         6.0        3.0
# 427        True         1.0        1.0
# 247        True         7.0        3.0
# 422        True         7.0        4.0
# 3          True         7.0        4.0
# 441        True         7.0        4.0
# 160        True         6.0        4.0
# 244        True         6.0        3.0
# 100        True         5.0        2.0
# 322        True         7.0        2.0
# 538       False         3.0        4.0
# 469        True         3.0        2.0
# 31         True         5.0        2.0
# 373        True         6.0        4.0
# 182        True         5.0        3.0
# 454       False         7.0        4.0
# 361        True         7.0        5.0
# 153       False         7.0        4.0
# 16        False         5.0        4.0
# 149        True         5.0        3.0
# 52         True         6.0        2.0
# 490        True         7.0        3.0
# 382        True         7.0        2.0
# 271        True         3.0        4.0
# 83         True         6.0        4.0
# 521        True         7.0        4.0
# 413        True         7.0        3.0

# %%
results.to_csv(os.path.join(pilot_path, 'results/first_pilot_results.csv'))

# %%
pickle.dump(continuous_annotations, open(os.path.join(pilot_path, 'results/first_pilot_continuous.pkl'), 'wb'))
