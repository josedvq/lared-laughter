# %%
library("ClusterBootstrap")
library("lme4")
library("lmerTest")

# %%
model.1 <- clusbootglm(pos ~ treat*time, data = medication, clusterid = id)

# %%
options(digits=3)
summary(model.1)
# Out:
# Call:
# clusbootglm(model = pos ~ treat * time, data = medication, clusterid = id)
#
#             Estimate Std.error CI 2.5% CI 97.5%
# (Intercept)   167.27      9.25  149.48   185.55
# treat          -6.36     12.47  -30.92    18.01
# time           -2.05      1.50   -4.56     1.56
# treat:time      5.68      2.24    1.48    10.12
# ---
# 95% confidence interval using bias corrected and accelerated cluster bootstrap intervals

# %% [markdown]
# # Loading results..

# %%
results = read.csv('results.csv')

# %% [markdown]
# # Intensity analysis

# %%
intensity_model.1 = lmer(intensity ~ (1|hit_id) + condition, data=results)

# %%
anova(intensity_model.1)
# Out:
#           Sum Sq Mean Sq NumDF DenDF F value Pr(>F)
# condition 26.2   13.1    2     3008  6.02    0.00246

# %%
intensity_model.2 <- clusbootglm(intensity ~ condition, data=results, clusterid = hit_id)

# %%
summary(intensity_model.2)
# Out:
# Call:
# clusbootglm(model = intensity ~ condition, data = results, clusterid = hit_id)
#
#                Estimate Std.error CI 2.5% CI 97.5%
# (Intercept)       3.965    0.0836   3.804   4.1324
# conditionav      -0.200    0.0747  -0.354  -0.0569
# conditionvideo   -0.202    0.0713  -0.340  -0.0578
# ---
# 95% confidence interval using bias corrected and accelerated cluster bootstrap intervals

# %% [markdown]
# # Confidence analysis

# %%
confidence_model.1 = lmer(confidence ~ (1|hit_id) + condition, data=results)

# %%
anova(confidence_model.1)
# Out:
#           Sum Sq   Mean Sq  NumDF DenDF    F value  Pr(>F)
# condition 455.8132 227.9066 2     3007.248 89.80603 1.312429e-38

# %%
summary(confidence_model.1)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: confidence ~ (1 | hit_id) + condition
#    Data: results
#
# REML criterion at convergence: 11599.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.2081 -0.5126  0.2222  0.6211  2.3590
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  hit_id   (Intercept) 1.069    1.034
#  Residual             2.538    1.593
# Number of obs: 3043, groups:  hit_id, 34
#
# Fixed effects:
#                  Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)       5.74314    0.18419   36.47588  31.181   <2e-16 ***
# conditionav      -0.02738    0.07091 3007.36901  -0.386    0.699
# conditionvideo   -0.83333    0.07054 3007.00905 -11.813   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) condtnv
# conditionav -0.191
# conditionvd -0.191  0.497

# %% [markdown]
# # Onset analysis

# %%
nrow(results)
# Out:
# [1] 3043

# %%
nrow(results[results$condition == 'audio',])
# Out:
# [1] 1020

# %%
glm_model.1 = lmer(onset ~ (1|hit_id) + condition + hash, data=results)

# %%
anova(glm_model.1)
# Out:
#           Sum Sq      Mean Sq  NumDF DenDF    F value  Pr(>F)
# condition    3.909567 1.954783   2   1423.827 4.177238  1.552924e-02
# hash      1309.595351 3.257700 402   1218.582 6.961481 1.153849e-152

# %%
summary(glm_model.1)
# Out:
# Correlation matrix not shown by default, as p = 405 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: onset ~ (1 | hit_id) + condition + hash
#    Data: results
#
# REML criterion at convergence: 3593.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.0494 -0.3003 -0.0162  0.3371  7.3002
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  hit_id   (Intercept) 0.02042  0.1429
#  Residual             0.46796  0.6841
# Number of obs: 1845, groups:  hit_id, 31
#
# Fixed effects:
#                                                                        Estimate
# (Intercept)                                                           3.387e+00
# conditionav                                                          -7.451e-02
# conditionvideo                                                        5.544e-02
# ...

# %%
model.1 <- clusbootglm(onset ~ condition+hash, data=results, clusterid = hit_id)

# %%
summary(model.1)
# Out:
# Call:
# clusbootglm(model = onset ~ condition + hash, data = results,
#     clusterid = hit_id)
#
#                                                                      Estimate
# (Intercept)                                                           4.26922
# conditionav                                                          -0.00193
# conditionvideo                                                        0.26380
# hash069d300af9889ef9b177b0158193da139d6872b5edd3b74a3016359a15cd2b8e -0.83008
# hash0f30b81afc28da6a261208efbf1623846f3253825d235b39274447d4cb8b2ed2 -0.01260
# hash0feb2d80d7e192750c723d7f70dd82b61f3e98de2a437542ae48f5408b073973 -2.21457
# hash1045f4f5af149c20d0bb3e7523013510912093312f6f56cf12cc66873b4a2c88 -1.08057
# hash11866b5358caabe46c4528bfc49de7579363607700b1cc865e5cba8cffe6007d  0.80273
# hash15422420846840e0319c3aa409b77dcad28633ea12a9af98c16bf5c1aa970312 -1.87789
# hash2070ebb6b8c1d14e2e2ba906e4f666d8aa694461f0e03de78a12fdbccd0003b1 -2.11653
# ...
