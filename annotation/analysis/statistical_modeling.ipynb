# %%
library("ClusterBootstrap")
library("lme4")
library("lmerTest")
# Out:
# Loading required package: parallel
#
# Loading required package: magrittr
#
# Loading required package: dplyr
#
#
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: Matrix
#
#
# Attaching package: 'lmerTest'
#
#
# The following object is masked from 'package:lme4':
#
#     lmer
#
#
# The following object is masked from 'package:stats':
#
#     step

# %%
model.1 <- clusbootglm(pos ~ treat*time, data = medication, clusterid = id)

# %%
options(digits=3)
summary(model.1)
# Out:
# Call:
# clusbootglm(model = pos ~ treat * time, data = medication, clusterid = id)
#
#             Estimate Std.error CI 2.5% CI 97.5%
# (Intercept)   167.29      9.08  150.22   185.58
# treat          -6.40     12.17  -29.47    18.14
# time           -2.05      1.48   -4.58     1.47
# treat:time      5.69      2.23    1.38    10.01
# ---
# 95% confidence interval using bias corrected and accelerated cluster bootstrap intervals

# %% [markdown]
# # Loading results..

# %%
results = read.csv('C:\\Users\\Jose\\gdrive\\data\\lared_laughter\\annotation_experiment_2\\processed\\examples_without_calibration.csv')

# %%
results = results[results$pressed_key == "True", ]

# %%
nrow(results)
# Out:
# [1] 2531

# %% [markdown]
# # Intensity analysis

# %%
intensity_model.1 = lmer(intensity ~ (1|instance_id) + condition, data=results)
anova(intensity_model.1)
# Out:
#           Sum Sq Mean Sq NumDF DenDF F value Pr(>F)
# condition 32.4   16.2    2     2486  6.12    0.00223

# %%
intensity_model.1 = lmer(norm_intensity ~ (1|instance_id) + condition, data=results)
anova(intensity_model.1)
# Out:
#           Sum Sq Mean Sq NumDF DenDF F value Pr(>F)
# condition 71.8   35.9    2     2495  13.9    9.78e-07

# %%
intensity_model.2 <- clusbootglm(intensity ~ condition, data=results, clusterid = instance_id)
summary(intensity_model.2)
# Out:
# Call:
# clusbootglm(model = intensity ~ condition, data = results, clusterid = instance_id)
#
#                Estimate Std.error CI 2.5% CI 97.5%
# (Intercept)       3.641     0.111    3.44   3.8796
# conditionav      -0.238     0.102   -0.44  -0.0406
# conditionvideo   -0.246     0.101   -0.45  -0.0482
# ---
# 95% confidence interval using bias corrected and accelerated cluster bootstrap intervals

# %%
intensity_model.2 <- clusbootglm(norm_intensity ~ condition, data=results, clusterid = instance_id)
summary(intensity_model.2)
# Out:
# Call:
# clusbootglm(model = norm_intensity ~ condition, data = results,
#     clusterid = instance_id)
#
#                Estimate Std.error CI 2.5% CI 97.5%
# (Intercept)       1.108    0.0597   0.990   1.2261
# conditionav      -0.068    0.0671  -0.198   0.0674
# conditionvideo    0.323    0.0753   0.180   0.4739
# ---
# 95% confidence interval using bias corrected and accelerated cluster bootstrap intervals

# %% [markdown]
# # Confidence analysis

# %%
confidence_model.1 = lmer(confidence ~ (1|hit_id) + condition, data=results)

# %%
anova(confidence_model.1)
# Out:
#           Sum Sq   Mean Sq  NumDF DenDF    F value  Pr(>F)
# condition 455.8132 227.9066 2     3007.248 89.80603 1.312429e-38

# %%
summary(confidence_model.1)
# Out:
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: confidence ~ (1 | hit_id) + condition
#    Data: results
#
# REML criterion at convergence: 11599.6
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -3.2081 -0.5126  0.2222  0.6211  2.3590
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  hit_id   (Intercept) 1.069    1.034
#  Residual             2.538    1.593
# Number of obs: 3043, groups:  hit_id, 34
#
# Fixed effects:
#                  Estimate Std. Error         df t value Pr(>|t|)
# (Intercept)       5.74314    0.18419   36.47588  31.181   <2e-16 ***
# conditionav      -0.02738    0.07091 3007.36901  -0.386    0.699
# conditionvideo   -0.83333    0.07054 3007.00905 -11.813   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Correlation of Fixed Effects:
#             (Intr) condtnv
# conditionav -0.191
# conditionvd -0.191  0.497

# %% [markdown]
# # Onset analysis

# %%
glm_model.1 = lmer(onset ~ (1|instance_id) + condition, data=results)

# %%
anova(glm_model.1)
# Out:
#           Sum Sq Mean Sq NumDF DenDF F value Pr(>F)
# condition 34.5   17.2    2     2501  15.7    1.7e-07

# %%
summary(glm_model.1)
# Out:
# Correlation matrix not shown by default, as p = 405 > 12.
# Use print(obj, correlation=TRUE)  or
#     vcov(obj)        if you need it
# Linear mixed model fit by REML. t-tests use Satterthwaite's method [
# lmerModLmerTest]
# Formula: onset ~ (1 | hit_id) + condition + hash
#    Data: results
#
# REML criterion at convergence: 3593.8
#
# Scaled residuals:
#     Min      1Q  Median      3Q     Max
# -6.0494 -0.3003 -0.0162  0.3371  7.3002
#
# Random effects:
#  Groups   Name        Variance Std.Dev.
#  hit_id   (Intercept) 0.02042  0.1429
#  Residual             0.46796  0.6841
# Number of obs: 1845, groups:  hit_id, 31
#
# Fixed effects:
#                                                                        Estimate
# (Intercept)                                                           3.387e+00
# conditionav                                                          -7.451e-02
# conditionvideo                                                        5.544e-02
# ...

# %%
model.1 <- clusbootglm(onset ~ condition, data=results, clusterid = instance_id)

# %%
summary(model.1)
# Out:
# Call:
# clusbootglm(model = onset ~ condition, data = results, clusterid = instance_id)
#
#                Estimate Std.error CI 2.5% CI 97.5%
# (Intercept)      3.0960    0.0357   3.028   3.1683
# conditionav     -0.0475    0.0477  -0.144   0.0459
# conditionvideo   0.2275    0.0658   0.103   0.3624
# ---
# 95% confidence interval using bias corrected and accelerated cluster bootstrap intervals

# %%
model.1 <- clusbootglm(onset ~ condition+hash, data=results, clusterid = instance_id)

# %%
summary(model.1)
# Out:
# Call:
# clusbootglm(model = onset ~ condition + hash, data = results,
#     clusterid = instance_id)
#
#                                                                      Estimate
# (Intercept)                                                           3.23381
# conditionav                                                          -0.06075
# conditionvideo                                                        0.16919
# hash006f74addfc99845bf6c9f80d13d52ccc189341031525530762bb83dd8b713af -0.87658
# hash0070b1ba6e8de828aea5c6d3b9d1c3662959fb5f032a679cac78e5ca98fcb1ff -0.15800
# hash00bcb7cfe796c64cf5fa4195248553f4a5937897650cee2e2bc2d80fba782667  0.62078
# hash00f8d1065ae383d5844c019807396b58e16bfb728f9bbc2fb9f84cb5126f31b7 -2.10653
# hash017d69fa136cb8b968493ef41d4adca5c53ab7d8e19a9de15baf6e306bbf7243 -0.47847
# hash01baf1c42d3d4d3d03cab574792d89e237d97f335967d1313a54dbb008e0c9ed -0.76059
# hash01d645b5651160faf98945b1676cd34288b343936a6c8cbe6812de354adb52d1  0.58649
# ...
