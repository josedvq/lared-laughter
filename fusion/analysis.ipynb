# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
from lared_laughter.fusion.utils import make_table, make_dataframe, make_heatmap

# %%
classification_res = pickle.load(open('results/classification.pkl', 'rb'))
regression_res = pickle.load(open('results/regression.pkl', 'rb'))

# %%
segmentation_res = {
    **pickle.load(open('results/segmentation.pkl', 'rb')),
    **pickle.load(open('results/segmentation2.pkl', 'rb')),
    **pickle.load(open('results/segmentation3.pkl', 'rb'))
}

# %%
fig = make_heatmap(classification_res)

# %%
fig.savefig('../figures/classification.png', dpi=300, bbox_inches="tight")

# %%
fig = make_heatmap(regression_res, reverse=True, fmt='%.2f')

# %%
fig.savefig('../figures/regression.png', dpi=300, bbox_inches="tight")

# %%
fig = make_heatmap(segmentation_res)

# %%
fig.savefig('../figures/segmentation.png', dpi=300, bbox_inches="tight")
